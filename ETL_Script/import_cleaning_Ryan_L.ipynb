# %%
import pandas as pd
import os

# %%
# Change this pathway to the directory where you have cloned the repository to

file_path = 'C:/Users/ryanl/Documents/Good Class Folder/Disney_wait_times/Metadata'

# %%
meta = os.path.join(file_path, 'metadata.csv')
meta_df = pd.read_csv(meta)

# %%
meta_df.shape
# Out:
# (2079, 181)

# %%
meta_df.head(5)
# Out:
#        DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  \
# 0  1/1/2015               NaN          5          0           0            1
# 1  1/2/2015               NaN          6          1           0            1
# 2  1/3/2015               NaN          7          2           0            1
# 3  1/4/2015               NaN          1          3           1            1
# 4  1/5/2015               NaN          2          4           1            1
#
#    YEAR          SEASON  HOLIDAYPX  HOLIDAYM  ... HSFIREWKS  AKPRDDAY  \
# 0  2015  CHRISTMAS PEAK          0         5  ...         1         0
# 1  2015       CHRISTMAS          2         5  ...         1         0
# 2  2015       CHRISTMAS          3         0  ...         1         0
# 3  2015       CHRISTMAS          4         0  ...         1         0
# 4  2015       CHRISTMAS          5         0  ...         1         0
#
#   AKPRDDT1 AKPRDDT2 AKPRDDN  AKFIREN  AKSHWNGT AKSHWNT1  AKSHWNT2  AKSHWNN
# 0      NaN      NaN     NaN      NaN         0      NaN       NaN      NaN
# 1      NaN      NaN     NaN      NaN         0      NaN       NaN      NaN
# 2      NaN      NaN     NaN      NaN         0      NaN       NaN      NaN
# 3      NaN      NaN     NaN      NaN         0      NaN       NaN      NaN
# 4      NaN      NaN     NaN      NaN         0      NaN       NaN      NaN
#
# [5 rows x 181 columns]

# %%
meta_df = meta_df[['DATE', 'DAYOFWEEK', 'DAYOFYEAR', 'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',\
                   'WDWMEANTEMP', 'WEATHER_WDWPRECIP', 'inSession', 'inSession_Florida']]

# %%
meta_df = meta_df.rename(columns={'DATE': 'date', 'DAYOFWEEK': 'day_week', 'DAYOFYEAR': 'day_year', 'WEEKOFYEAR': 'week_year', 'MONTHOFYEAR': 'month_year', \
                          'YEAR': 'year', 'HOLIDAYPX': 'prox_to_holiday', 'WDWMEANTEMP': 'wdw_mean_temp', 'WEATHER_WDWPRECIP': 'wdw_precip', 'inSession': 'schools_in_session', \
                          'inSession_Florida': 'florida_schools_in_session'})

# %%
meta_df.head()
# Out:
#        date  day_week  day_year  week_year  month_year  year  prox_to_holiday  \
# 0  1/1/2015         5         0          0           1  2015                0
# 1  1/2/2015         6         1          0           1  2015                2
# 2  1/3/2015         7         2          0           1  2015                3
# 3  1/4/2015         1         3          1           1  2015                4
# 4  1/5/2015         2         4          1           1  2015                5
#
#    wdw_mean_temp  wdw_precip  schools_in_session  florida_schools_in_session
# 0          66.41        0.12                0.00                        0.00
# 1          69.36        0.12                0.00                        0.00
# 2          75.22        0.07                0.00                        0.00
# 3          75.95        0.12                0.67                        0.79
# 4          64.60        0.12                0.67                        0.79

# %%
meta_df.shape
# Out:
# (2079, 11)

# %%
meta_df.count()
# Out:
# date                          2079
# day_week                      2079
# day_year                      2079
# week_year                     2079
# month_year                    2079
# year                          2079
# prox_to_holiday               2079
# wdw_mean_temp                 2073
# wdw_precip                    2079
# schools_in_session            1974
# florida_schools_in_session    1974
# dtype: int64

# %%
meta_df.isnull().sum()
# Out:
# date                            0
# day_week                        0
# day_year                        0
# week_year                       0
# month_year                      0
# year                            0
# prox_to_holiday                 0
# wdw_mean_temp                   6
# wdw_precip                      0
# schools_in_session            105
# florida_schools_in_session    105
# dtype: int64

# %%
meta_df_null = meta_df.isnull()
meta_df_null_rows = meta_df_null.any(axis=1)

meta_df_null_rows_subset = meta_df[meta_df_null_rows]
meta_df_null_rows_subset = meta_df_null_rows_subset[['month_year', 'year', 'wdw_mean_temp', 'florida_schools_in_session']]
meta_df_null_rows_subset = meta_df_null_rows_subset.groupby(['month_year','year']).apply(lambda x: x.isnull().sum())
meta_df_null_rows_subset
# Out:
#                  month_year  year  wdw_mean_temp  florida_schools_in_session
# month_year year
# 1          2017           0     0              1                           0
#            2021           0     0              0                           1
# 4          2017           0     0              3                           0
#            2021           0     0              0                           1
# 5          2021           0     0              0                          15
# 6          2019           0     0              0                           1
#            2021           0     0              0                          25
# 7          2021           0     0              0                          31
# 8          2021           0     0              0                          31
# 11         2016           0     0              1                           0
# 12         2016           0     0              1                           0

# %%
meta_df.dtypes
# Out:
# date                           object
# day_week                        int64
# day_year                        int64
# week_year                       int64
# month_year                      int64
# year                            int64
# prox_to_holiday                 int64
# wdw_mean_temp                 float64
# wdw_precip                    float64
# schools_in_session            float64
# florida_schools_in_session    float64
# dtype: object

# %%
meta_df.isnull()
# Out:
#        date  day_week  day_year  week_year  month_year   year  \
# 0     False     False     False      False       False  False
# 1     False     False     False      False       False  False
# 2     False     False     False      False       False  False
# 3     False     False     False      False       False  False
# 4     False     False     False      False       False  False
# ...     ...       ...       ...        ...         ...    ...
# 2074  False     False     False      False       False  False
# 2075  False     False     False      False       False  False
# 2076  False     False     False      False       False  False
# 2077  False     False     False      False       False  False
# 2078  False     False     False      False       False  False
#
#       prox_to_holiday  wdw_mean_temp  wdw_precip  schools_in_session  \
# 0               False          False       False               False
# 1               False          False       False               False
# 2               False          False       False               False
# 3               False          False       False               False
# 4               False          False       False               False
# ...               ...            ...         ...                 ...
# 2074            False          False       False                True
# 2075            False          False       False                True
# 2076            False          False       False                True
# 2077            False          False       False                True
# 2078            False          False       False                True
#
#       florida_schools_in_session
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 2074                        True
# 2075                        True
# 2076                        True
# 2077                        True
# 2078                        True
#
# [2079 rows x 11 columns]

# %%
meta_df = meta_df.dropna()

# %%
meta_df
# Out:
#             date  day_week  day_year  week_year  month_year  year  \
# 0       1/1/2015         5         0          0           1  2015
# 1       1/2/2015         6         1          0           1  2015
# 2       1/3/2015         7         2          0           1  2015
# 3       1/4/2015         1         3          1           1  2015
# 4       1/5/2015         2         4          1           1  2015
# ...          ...       ...       ...        ...         ...   ...
# 1970  12/27/2020         1       361         52          12  2020
# 1971  12/28/2020         2       362         52          12  2020
# 1972  12/29/2020         3       363         52          12  2020
# 1973  12/30/2020         4       364         52          12  2020
# 1974  12/31/2020         5       365         52          12  2020
#
#       prox_to_holiday  wdw_mean_temp  wdw_precip  schools_in_session  \
# 0                   0          66.41        0.12                0.00
# 1                   2          69.36        0.12                0.00
# 2                   3          75.22        0.07                0.00
# 3                   4          75.95        0.12                0.67
# 4                   5          64.60        0.12                0.67
# ...               ...            ...         ...                 ...
# 1970                3          74.50        0.08                0.00
# 1971                4          72.93        0.08                0.00
# 1972                3          74.50        0.04                0.00
# 1973                2          74.39        0.08                0.00
# 1974                0          60.38        0.08                0.00
#
#       florida_schools_in_session
# 0                           0.00
# 1                           0.00
# 2                           0.00
# 3                           0.79
# 4                           0.79
# ...                          ...
# 1970                        0.00
# 1971                        0.00
# 1972                        0.00
# 1973                        0.00
# 1974                        0.00
#
# [1968 rows x 11 columns]

# %%
meta_df.isnull().sum()
# Out:
# date                          0
# day_week                      0
# day_year                      0
# week_year                     0
# month_year                    0
# year                          0
# prox_to_holiday               0
# wdw_mean_temp                 0
# wdw_precip                    0
# schools_in_session            0
# florida_schools_in_session    0
# dtype: int64
