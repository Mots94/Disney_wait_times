# %%
import pandas as pd
import os

# %%
# Change this pathway to the directory where you have cloned the repository to

file_path = 'C:/Users/ryanl/Documents/Good Class Folder/Disney_wait_times'

# %%
meta = os.path.join(file_path, 'metadata.csv')
meta_df = pd.read_csv(meta)

# %%
meta_df.shape
# Out:
# (2079, 181)

# %%
meta_df.head(5)
# Out:
#          DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# 0  01/01/2015               NaN          5          0           0
# 1  01/02/2015               NaN          6          1           0
# 2  01/03/2015               NaN          7          2           0
# 3  01/04/2015               NaN          1          3           1
# 4  01/05/2015               NaN          2          4           1
#
#    MONTHOFYEAR  YEAR          SEASON  HOLIDAYPX  HOLIDAYM  ... HSFIREWKS  \
# 0            1  2015  CHRISTMAS PEAK          0         5  ...         1
# 1            1  2015       CHRISTMAS          2         5  ...         1
# 2            1  2015       CHRISTMAS          3         0  ...         1
# 3            1  2015       CHRISTMAS          4         0  ...         1
# 4            1  2015       CHRISTMAS          5         0  ...         1
#
#    AKPRDDAY AKPRDDT1 AKPRDDT2 AKPRDDN  AKFIREN  AKSHWNGT AKSHWNT1  AKSHWNT2  \
# ...

# %%
meta_df = meta_df[['DATE', 'DAYOFWEEK', 'DAYOFYEAR', 'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',\
                   'WDWMEANTEMP', 'WEATHER_WDWPRECIP', 'inSession', 'inSession_Florida']]

# %%
meta_df = meta_df.rename(columns={'DATE': 'date', 'DAYOFWEEK': 'day_week', 'DAYOFYEAR': 'day_year', 'WEEKOFYEAR': 'week_year', 'MONTHOFYEAR': 'month_year', \
                          'YEAR': 'year', 'HOLIDAYPX': 'prox_to_holiday', 'WDWMEANTEMP': 'wdw_mean_temp', 'WEATHER_WDWPRECIP': 'wdw_precip', 'inSession': 'schools_in_session', \
                          'inSession_Florida': 'florida_schools_in_session'})

# %%
meta_df.head()
# Out:
#          date  day_week  day_year  week_year  month_year  year  \
# 0  01/01/2015         5         0          0           1  2015
# 1  01/02/2015         6         1          0           1  2015
# 2  01/03/2015         7         2          0           1  2015
# 3  01/04/2015         1         3          1           1  2015
# 4  01/05/2015         2         4          1           1  2015
#
#    prox_to_holiday  wdw_mean_temp  wdw_precip schools_in_session  \
# 0                0          66.41        0.12                 0%
# 1                2          69.36        0.12                 0%
# 2                3          75.22        0.07                 0%
# 3                4          75.95        0.12                67%
# 4                5          64.60        0.12                67%
#
#   florida_schools_in_session
# 0                         0%
# 1                         0%
# 2                         0%
# 3                        79%
# 4                        79%

# %%
meta_df.shape
# Out:
# (2079, 11)

# %%
meta_df.count()
# Out:
# date                          2079
# day_week                      2079
# day_year                      2079
# week_year                     2079
# month_year                    2079
# year                          2079
# prox_to_holiday               2079
# wdw_mean_temp                 2073
# wdw_precip                    2079
# schools_in_session            1974
# florida_schools_in_session    1974
# dtype: int64

# %%
meta_df.isnull().sum()
# Out:
# date                            0
# day_week                        0
# day_year                        0
# week_year                       0
# month_year                      0
# year                            0
# prox_to_holiday                 0
# wdw_mean_temp                   6
# wdw_precip                      0
# schools_in_session            105
# florida_schools_in_session    105
# dtype: int64

# %%
meta_df_null = meta_df.isnull()
meta_df_null_rows = meta_df_null.any(axis=1)

meta_df_null_rows_subset = meta_df[meta_df_null_rows]
meta_df_null_rows_subset = meta_df_null_rows_subset[['month_year', 'year', 'wdw_mean_temp', 'florida_schools_in_session']]
meta_df_null_rows_subset = meta_df_null_rows_subset.groupby(['month_year','year']).apply(lambda x: x.isnull().sum())
meta_df_null_rows_subset
# Out:
#                  month_year  year  wdw_mean_temp  florida_schools_in_session
# month_year year
# 1          2017           0     0              1                           0
#            2021           0     0              0                           1
# 4          2017           0     0              3                           0
#            2021           0     0              0                           1
# 5          2021           0     0              0                          15
# 6          2019           0     0              0                           1
#            2021           0     0              0                          25
# 7          2021           0     0              0                          31
# 8          2021           0     0              0                          31
# 11         2016           0     0              1                           0
# 12         2016           0     0              1                           0

# %%
meta_df.dtypes
# Out:
# date                           object
# day_week                        int64
# day_year                        int64
# week_year                       int64
# month_year                      int64
# year                            int64
# prox_to_holiday                 int64
# wdw_mean_temp                 float64
# wdw_precip                    float64
# schools_in_session             object
# florida_schools_in_session     object
# dtype: object

# %%
meta_df.isnull()
# Out:
#        date  day_week  day_year  week_year  month_year   year  \
# 0     False     False     False      False       False  False
# 1     False     False     False      False       False  False
# 2     False     False     False      False       False  False
# 3     False     False     False      False       False  False
# 4     False     False     False      False       False  False
# ...     ...       ...       ...        ...         ...    ...
# 2074  False     False     False      False       False  False
# 2075  False     False     False      False       False  False
# 2076  False     False     False      False       False  False
# 2077  False     False     False      False       False  False
# 2078  False     False     False      False       False  False
#
#       prox_to_holiday  wdw_mean_temp  wdw_precip  schools_in_session  \
# 0               False          False       False               False
# 1               False          False       False               False
# ...

# %%
meta_df.fillna(0)
# Out:
#             date  day_week  day_year  week_year  month_year  year  \
# 0     01/01/2015         5         0          0           1  2015
# 1     01/02/2015         6         1          0           1  2015
# 2     01/03/2015         7         2          0           1  2015
# 3     01/04/2015         1         3          1           1  2015
# 4     01/05/2015         2         4          1           1  2015
# ...          ...       ...       ...        ...         ...   ...
# 2074  08/27/2021         6       238         34           8  2021
# 2075  08/28/2021         7       239         34           8  2021
# 2076  08/29/2021         1       240         35           8  2021
# 2077  08/30/2021         2       241         35           8  2021
# 2078  08/31/2021         3       242         35           8  2021
#
#       prox_to_holiday  wdw_mean_temp  wdw_precip schools_in_session  \
# 0                   0          66.41        0.12                 0%
# ...

# %%
meta_df[["schools_in_session", "florida_schools_in_session"]] = meta_df[["schools_in_session", "florida_schools_in_session"]].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b026826a759c> in <module>
# ----> 1 meta_df[["schools_in_session", "florida_schools_in_session"]] = meta_df[["schools_in_session", "florida_schools_in_session"]].astype(float)
#
# c:\Users\ryanl\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\Users\ryanl\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...
